# %% [markdown]
# # 종합실습3 이변량분석(y-범주) : 직원 이직 분석

# %% [markdown]
# ![](https://www.talentalign.com/wp-content/uploads/2019/09/main-qimg-2434943004743f79c0abf540cb4f6e2c-cropped.jpg)

# %% [markdown]
# * 직원 이직 분석
#     * 회사에서 최근 1~2년 사이 이직률이 상승하였습니다.
#     * 여러분은, 직원들이 이직하는데 중요한 요인이 무엇인지 데이터를 기반으로 한 분석을 의뢰 받았습니다.

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic      #mosaic plot!

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.

# %%
# 직원 이직 데이터
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple2.CSV'
data = pd.read_csv(path)  
data.head(5)
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   33                 7             817    Male                3
# 1          0   35                18            1412    Male                4
# 2          0   42                 6            1911    Male                1
# 3          0   46                 2            1204  Female                1
# 4          1   22                 4             593    Male                3
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0       Married          11691       No                 11                 14
# 1        Single           9362       No                 11                 10
# 2       Married          13348       No                 13                 18
# 3       Married          17048       No                 23                 28
# 4        Single           3894       No                 16                  4

# %% [markdown]
# > * 변수설명
#     * Attrition	:	이직여부, Yes , No (Target)
#     * Age	:	나이
#     * DistanceFromHome	:	집-직장 거리(마일)
#     * EmployeeNumber	:	사번
#     * Gender	:	성별(Male, Female)
#     * JobSatisfaction	:	직무 만족도, 다음시트 참조
#     * MaritalStatus	:	결혼상태(Married, Single, Divorced)
#     * MonthlyIncome	:	월급(달러)
#     * OverTime	:	야근여부
#     * PercentSalaryHike	:	전년대비 급여인상율(%)
#     * TotalWorkingYears	:	총 근무 연수

# %% [markdown]
# # 2.범주-->범주

# %%
target = 'Attrition'

# %% [markdown]
# ## (1) Gender --> Attrition

# %%
feature = 'Gender'

# %% [markdown]
# * 교차표

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
pd.crosstab(data[target], data[feature])
# Out:
# Gender     Female  Male
# Attrition
# 0             403   598
# 1              66   129

# %%
pd.crosstab(data[target], data[feature], normalize = 'columns')
# 이직율은 다르다 그래서 3%면 차이나는것이다.
# 6시간 52분 듣기
# Out:
# Gender       Female      Male
# Attrition
# 0          0.859275  0.822558
# 1          0.140725  0.177442

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()
# 수치로는 의미 없지만, 비지니스 관점에서는 의미가 있다

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
# 먼저 집계
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('자유도',result[2])
print('기대빈도\n',result[3])

# 이직율의 기존 변동폭을 알아야하한다.
# Out:
# 교차표
#  Gender     Female  Male
# Attrition
# 0             403   598
# 1              66   129
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 2.5537631338119975
# p-value 0.1100318964829815
# 자유도 1
# 기대빈도
#  [[392.5326087 608.4673913]
#  [ 76.4673913 118.5326087]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (2) JobSatisfaction --> Attrition

# %%
feature = 'JobSatisfaction'

# %% [markdown]
# * 교차표

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
pd.crosstab(data[target], data[feature])
# Out:
# JobSatisfaction    1    2    3    4
# Attrition
# 0                191  189  295  326
# 1                 52   37   59   47

# %%
pd.crosstab(data[target], data[feature], normalize = 'columns')
# Out:
# JobSatisfaction         1         2         3         4
# Attrition
# 0                0.786008  0.836283  0.833333  0.873995
# 1                0.213992  0.163717  0.166667  0.126005

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
# 먼저 집계
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('자유도',result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  JobSatisfaction    1    2    3    4
# Attrition
# 0                191  189  295  326
# 1                 52   37   59   47
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 8.40684948576828
# p-value 0.0383107376547955
# 자유도 3
# 기대빈도
#  [[203.38043478 189.15217391 296.2826087  312.18478261]
#  [ 39.61956522  36.84782609  57.7173913   60.81521739]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (3) MaritalStatus --> Attrition

# %% [markdown]
# * 교차표

# %% [markdown]
# * 시각화

# %% [markdown]
# * 수치화 : 카이제곱검정

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (4) OverTime --> Attrition

# %% [markdown]
# * 교차표

# %% [markdown]
# * 시각화

# %% [markdown]
# * 수치화 : 카이제곱검정

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# # 3.숫자-->범주

# %% [markdown]
# ## (1) Age --> Attrition

# %%
feature = 'Age'

# %%
sns.kdeplot(x= feature, data = data, hue = target, common_norm = False)
plt.grid()
plt.show()

# %%
sns.kdeplot(x= feature, data = data, hue = target, multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (2) DistanceFromHome --> Attrition

# %%
feature = 'DistanceFromHome'

# %%
sns.kdeplot(x= feature, data = data, hue = target, common_norm = False)
plt.grid()
plt.show()

# %%
sns.kdeplot(x= feature, data = data, hue = target, multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')
plt.grid()
plt.show()

# %%
def eda2_nc(data, target, var) :
    plt.figure(figsize=(8,10))
    plt.subplot(2,1,1)
    sns.kdeplot(x= var, data = data, hue = target, common_norm = False)
    plt.grid()
    
    plt.subplot(2,1,2)
    sns.kdeplot(x= var, data = data, hue = target, multiple = 'fill')
    plt.axhline(data[target].mean(), color = 'r')
    plt.grid()
    plt.show()

# %%
print(eda2_nc(data, target, var))

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (3) MonthlyIncome --> Attrition

# %%
print(eda2_nc(data, 'Attrition', 'MonthlyIncome'))
# Out:
# None

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (4) PercentSalaryHike --> Attrition

# %%
print(eda2_nc(data, target, 'PercentSalaryHike'))
# Out:
# None

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## (5) TotalWorkingYears --> Attrition

# %%
print(eda2_nc(data, target, 'TotalWorkingYears'))
# Out:
# None

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# # 4.관계 정리하기

# %% [markdown]
# ① 강한관계

# %% [markdown]
# ② 중간관계

# %% [markdown]
# ③ 관계없음

# %%
# https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv
